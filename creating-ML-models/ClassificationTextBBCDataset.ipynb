# %% [markdown]
# # Implementing classification algorithms when working with text data
#
# This notebook will use the text dataset from BBC to show how we can take textual data points and perfom classification on them

# %%
import pandas as pd

# %% [markdown]
# ### BBC Text Dataset
# Source : https://www.kaggle.com/yufengdev/bbc-fulltext-and-category/downloads/bbc-text.csv
#
# category: One of 5 categories
#
# text: The title and body of the article, concatenated.

# %%
data = pd.read_csv('datasets/bbc-text.csv')

data.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %% [markdown]
# ### Unique category in data

# %%
data.category.unique()
# Out:
# array(['tech', 'business', 'sport', 'entertainment', 'politics'],
#       dtype=object)

# %% [markdown]
# ### Count each unique category frequency

# %%
data['category'].value_counts()
# Out:
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: category, dtype: int64

# %%
data.shape
# Out:
# (2225, 2)

# %%
data['text'][15]
# Out:
# 's korean credit card firm rescued south korea s largest credit card firm has averted liquidation following a one trillion won ($960m; £499m) bail-out.  lg card had been threatened with collapse because of its huge debts but the firm s creditors and its former parent have stepped in to rescue it. a consortium of creditors and lg group  a family owned conglomerate  have each put up $480m to stabilise the firm. lg card has seven million customers and its collapse would have sent shockwaves through the country s economy.  the firm s creditors - which own 99% of lg card - have been trying to agree a deal to secure its future for several weeks. they took control of the company in january when it avoided bankruptcy only through a $4.5bn bail-out.  they had threatened to delist the company  a move which would have triggered massive debt redemptions and forced the company into bankruptcy  unless agreement was reached on its future funding.  lg card will not need any more financial aid after this   laah chong-gyu  executive director of korea development bank - one of the firm s creditors - said.  the agreement will see some 12 trillion won of debt converted into equity.  the purpose of the capital injection is to avoid delisting and the goal will be met   david kim  an analyst at sejong securities  told reuters. south korea s consumer credit market has been slowly recovering from a crisis in 2002 when a credit bubble burst and millions of consumers fell behind on their debt repayments. lg card returned to profit in september but needed further capital to avoid being thrown off the market. south korea s stock exchange can delist any firm if its debt exceeds its assets two years running.'

# %% [markdown]
# ### Transforming text using count encoding

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer()
x_train_count = count_vectorizer.fit_transform(data['text'])

count_vectorizer.vocabulary_
# Out:
# {'tv': 27299,
#  'future': 11495,
#  'in': 13801,
#  'the': 26462,
#  'hands': 12561,
#  'of': 18726,
#  'viewers': 28191,
#  'with': 28955,
#  'home': 13183,
#  'theatre': 26464,
#  'systems': 26007,
#  'plasma': 20146,
#  'high': 13002,
#  'definition': 7862,
#  'tvs': 27302,
#  'and': 2429,
#  'digital': 8332,
#  'video': 28174,
#  'recorders': 21691,
#  'moving': 17832,
#  'into': 14340,
#  'living': 16089,
#  'room': 22779,
#  'way': 28572,
#  'people': 19740,
#  'watch': 28540,
#  'will': 28852,
#  'be': 3620,
#  'radically': 21317,
#  'different': 8316,
#  'five': 10875,
#  'years': 29260,
#  'time': 26665,
#  'that': 26454,
#  'is': 14510,
#  'according': 1650,
#  'to': 26730,
#  'an': 2395,
#  'expert': 10212,
#  'panel': 19383,
#  'which': 28749,
#  'gathered': 11644,
#  'at': 2994,
#  'annual': 2524,
#  'consumer': 6764,
#  'electronics': 9414,
#  'show': 24042,
#  'las': 15561,
#  'vegas': 28057,
#  'discuss': 8504,
#  'how': 13346,
#  'these': 26500,
#  'new': 18278,
#  'technologies': 26246,
#  'impact': 13703,
#  'one': 18837,
#  'our': 19052,
#  'favourite': 10530,
#  'pastimes': 19544,
#  'us': 27901,
#  'leading': 15662,
#  'trend': 27085,
#  'programmes': 20844,
#  'other': 19039,
#  'content': 6796,
#  'delivered': 7927,
#  'via': 28137,
#  'networks': 18258,
#  'through': 26588,
#  'cable': 5004,
#  'satellite': 23173,
#  'telecoms': 26281,
#  'companies': 6390,
#  'broadband': 4665,
#  'service': 23722,
#  'providers': 20990,
#  'front': 11379,
#  'rooms': 22780,
#  'portable': 20380,
#  'devices': 8231,
#  'most': 17758,
#  'talked': 26079,
#  'about': 1551,
#  'ces': 5519,
#  'has': 12684,
#  'been': 3706,
#  'personal': 19833,
#  'dvr': 9143,
#  'pvr': 21153,
#  'set': 23729,
#  'top': 26806,
#  'boxes': 4460,
#  'like': 15949,
#  'tivo': 26724,
#  'uk': 27376,
#  'sky': 24327,
#  'system': 26004,
#  'allow': 2219,
#  'record': 21687,
#  'store': 25345,
#  'play': 20163,
#  'pause': 19594,
#  'forward': 11197,
#  'wind': 28884,
#  'when': 28740,
#  'they': 26501,
#  'want': 28464,
#  'essentially': 9916,
#  'technology': 26248,
#  'allows': 2225,
#  'for': 11102,
#  'much': 17871,
#  'more': 17721,
#  'personalised': 19836,
#  'are': 2741,
#  'also': 2251,
#  'being': 3744,
#  'built': 4826,
#  'sets': 23735,
#  'big': 3961,
#  'business': 4934,
#  'japan': 14664,
#  'but': 4944,
#  'slower': 24426,
#  'take': 26057,
#  'off': 18730,
#  'europe': 9974,
#  'because': 3672,
#  'lack': 15433,
#  'programming': 20845,
#  'not': 18502,
#  'only': 18849,
#  'can': 5112,
#  'adverts': 1892,
#  'forget': 11147,
#  'abiding': 1532,
#  'by': 4980,
#  'network': 18255,
#  'channel': 5596,
#  'schedules': 23305,
#  'putting': 21148,
#  'together': 26744,
#  'their': 26471,
#  'own': 19254,
#  'la': 15416,
#  'carte': 5305,
#  'entertainment': 9746,
#  'some': 24635,
#  'worried': 29091,
#  'what': 28726,
#  'it': 14557,
#  'means': 17037,
#  'them': 26474,
#  'terms': 26372,
#  'advertising': 1891,
#  'revenues': 22427,
#  'as': 2868,
#  'well': 28674,
#  'brand': 4512,
#  'identity': 13568,
#  'viewer': 28190,
#  'loyalty': 16278,
#  'channels': 5598,
#  'although': 2262,
#  'leads': 15664,
#  'this': 26531,
#  'moment': 17639,
#  'concern': 6521,
#  'raised': 21374,
#  'particularly': 19493,
#  'growing': 12313,
#  'uptake': 27879,
#  'services': 23723,
#  'happens': 12595,
#  'here': 12930,
#  'today': 26737,
#  'we': 28581,
#  'see': 23558,
#  'nine': 18387,
#  'months': 17692,
#  'adam': 1753,
#  'hume': 13412,
#  'bbc': 3613,
#  'broadcast': 4667,
#  'futurologist': 11500,
#  'told': 26754,
#  'news': 18296,
#  'website': 28622,
#  'likes': 15959,
#  'there': 26490,
#  'no': 18414,
#  'issues': 14553,
#  'lost': 16237,
#  'revenue': 22426,
#  'yet': 29276,
#  'pressing': 20647,
#  'issue': 14549,
#  'commercial': 6342,
#  'broadcasters': 4669,
#  'important': 13748,
#  'everyone': 10039,
#  'talking': 26081,
#  'brands': 4517,
#  'rather': 21476,
#  'than': 26445,
#  'said': 23041,
#  'tim': 26662,
#  'hanlon': 12576,
#  'from': 11377,
#  'communications': 6378,
#  'firm': 10842,
#  'starcom': 25125,
#  'mediavest': 17070,
#  'reality': 21556,
#  'connections': 6653,
#  'anybody': 2582,
#  'producer': 20803,
#  'he': 12765,
#  'added': 1772,
#  'challenge': 5558,
#  'now': 18557,
#  'hard': 12610,
#  'promote': 20879,
#  'programme': 20840,
#  'so': 24554,
#  'choice': 5783,
#  'stacey': 25040,
#  'jolna': 14835,
#  'senior': 23642,
#  'vice': 28151,
#  'president': 20637,
#  'guide': 12358,
#  'group': 12306,
#  'find': 10775,
#  'simplified': 24197,
#  'or': 18936,
#  'could': 7070,
#  'leaf': 15666,
#  'out': 19058,
#  'google': 12066,
#  'book': 4325,
#  'search': 23493,
#  'engine': 9678,
#  'instead': 14183,
#  'scheduler': 23304,
#  'help': 12892,
#  'kind': 15209,
#  'model': 17580,
#  'might': 17328,
#  'work': 29060,
#  'younger': 29308,
#  'ipod': 14444,
#  'generation': 11723,
#  'used': 27912,
#  'taking': 26065,
#  'control': 6861,
#  'gadgets': 11517,
#  'on': 18832,
#  'suit': 25656,
#  'recognised': 21664,
#  'older': 18796,
#  'generations': 11724,
#  'comfortable': 6309,
#  'familiar': 10428,
#  'know': 15292,
#  'getting': 11804,
#  'perhaps': 19783,
#  'do': 8728,
#  'put': 21143,
#  'mr': 17855,
#  'suggested': 25645,
#  'end': 9620,
#  'you': 29305,
#  'have': 12726,
#  'kids': 15179,
#  'just': 14959,
#  'diapers': 8273,
#  'who': 28793,
#  'pushing': 21142,
#  'buttons': 4961,
#  'already': 2249,
#  'everything': 10040,
#  'possible': 20427,
#  'available': 3173,
#  'ultimately': 27387,
#  'tell': 26306,
#  'market': 16732,
#  '50': 979,
#  '000': 1,
#  'showcased': 24046,
#  'many': 16663,
#  'enhancing': 9693,
#  'watching': 28548,
#  'experience': 10203,
#  'everywhere': 10041,
#  'models': 17583,
#  'lcd': 15649,
#  'liquid': 16032,
#  'crystal': 7362,
#  'display': 8583,
#  'launched': 15598,
#  'capability': 5168,
#  'external': 10287,
#  'such': 25610,
#  'example': 10079,
#  'humax': 13406,
#  '26': 601,
#  'inch': 13833,
#  '80': 1296,
#  'hour': 13325,
#  'dvd': 9140,
#  'recorder': 21690,
#  'biggest': 3963,
#  'directtv': 8410,
#  'even': 10015,
#  'its': 14571,
#  'branded': 4513,
#  '100': 69,
#  'hours': 13327,
#  'recording': 21692,
#  'instant': 14177,
#  'replay': 22153,
#  'function': 11443,
#  'rewind': 22477,
#  'up': 27829,
#  '90': 1389,
#  'microsoft': 17303,
#  'chief': 5741,
#  'bill': 3973,
#  'gates': 11639,
#  'announced': 2513,
#  'his': 13073,
#  'pre': 20525,
#  'keynote': 15138,
#  'speech': 24832,
#  'partnership': 19505,
#  'called': 5056,
#  'tivotogo': 26726,
#  'recorded': 21689,
#  'windows': 28890,
#  'pcs': 19637,
#  'mobile': 17564,
#  'all': 2180,
#  'reflect': 21799,
#  'increasing': 13875,
#  'freeing': 11316,
#  'multimedia': 17912,
#  'worldcom': 29085,
#  'boss': 4394,
#  'left': 15729,
#  'books': 4336,
#  'alone': 2239,
#  'former': 11166,
#  'bernie': 3871,
#  'ebbers': 9238,
#  'accused': 1680,
#  'overseeing': 19204,
#  '11bn': 133,
#  '8bn': 1382,
#  'fraud': 11289,
#  'never': 18268,
#  'made': 16433,
#  'accounting': 1660,
#  'decisions': 7755,
#  'witness': 28972,
#  'jurors': 14956,
#  'david': 7643,
#  'myers': 17998,
#  'comments': 6340,
#  'under': 27490,
#  'questioning': 21226,
#  'defence': 7831,
#  'lawyers': 15635,
#  'arguing': 2759,
#  'was': 28521,
#  'responsible': 22298,
#  'problems': 20777,
#  'phone': 19952,
#  'company': 6393,
#  'collapsed': 6226,
#  '2002': 473,
#  'prosecutors': 20937,
#  'claim': 5924,
#  'losses': 16235,
#  'were': 28694,
#  'hidden': 12991,
#  'protect': 20951,
#  'shares': 23852,
#  'pleaded': 20186,
#  'guilty': 12372,
#  'assisting': 2957,
#  'monday': 17647,
#  'lawyer': 15634,
#  'reid': 21904,
#  'weingarten': 28655,
#  'tried': 27119,
#  'distance': 8625,
#  'client': 6034,
#  'allegations': 2191,
#  'during': 9128,
#  'cross': 7305,
#  'examination': 10074,
#  'asked': 2905,
#  'if': 13597,
#  'ever': 10025,
#  'knew': 15271,
#  'make': 16519,
#  'decision': 7754,
#  'am': 2280,
#  'aware': 3214,
#  'replied': 22158,
#  'did': 8295,
#  'entry': 9774,
#  'pressed': 20645,
#  'admitted': 1835,
#  'ordered': 18950,
#  'false': 10418,
#  'entries': 9772,
#  'request': 22196,
#  'financial': 10766,
#  'officer': 18747,
#  'scott': 23399,
#  'sullivan': 25671,
#  'trying': 27217,
#  'paint': 19325,
#  'testify': 26401,
#  'later': 15575,
#  'trial': 27098,
#  'mastermind': 16827,
#  'behind': 3737,
#  'house': 13328,
#  'cards': 5227,
#  'team': 26223,
#  'meanwhile': 17040,
#  'looking': 16199,
#  'portray': 20399,
#  'him': 13037,
#  'affable': 1921,
#  'admission': 1830,
#  'pe': 19644,
#  'graduate': 12137,
#  'economist': 9270,
#  'whatever': 28727,
#  'abilities': 1534,
#  'transformed': 27004,
#  'relative': 21968,
#  'unknown': 27675,
#  '160bn': 254,
#  'giant': 11826,
#  'investor': 14405,
#  'darling': 7611,
#  'late': 15573,
#  '1990s': 447,
#  'mounted': 17808,
#  'however': 13353,
#  'competition': 6424,
#  'increased': 13873,
#  'boom': 4340,
#  'petered': 19881,
#  'finally': 10761,
#  'shareholders': 23849,
#  '180bn': 315,
#  '20': 467,
#  'workers': 29064,
#  'jobs': 14793,
#  'expected': 10193,
#  'last': 15568,
#  'two': 27328,
#  'found': 11211,
#  'ceo': 5500,
#  'faces': 10342,
#  'substantial': 25576,
#  'jail': 14621,
#  'sentence': 23661,
#  'firmly': 10846,
#  'declared': 7768,
#  'innocence': 14100,
#  'tigers': 26649,
#  'wary': 28520,
#  'farrell': 10486,
#  'gamble': 11563,
#  'leicester': 15761,
#  'say': 23229,
#  'rushed': 22956,
#  'making': 16529,
#  'bid': 3953,
#  'andy': 2448,
#  'should': 24031,
#  'great': 12204,
#  'britain': 4645,
#  'rugby': 22909,
#  'league': 15669,
#  'captain': 5197,
#  'decide': 7746,
#  'switch': 25944,
#  'codes': 6178,
#  'else': 9470,
#  'involved': 14423,
#  'process': 20787,
#  'still': 25278,
#  'away': 3216,
#  'going': 12021,
#  'next': 18306,
#  'stage': 25050,
#  'john': 14809,
#  'wells': 28681,
#  'radio': 21321,
#  'lot': 16239,
#  'unknowns': 27676,
#  'least': 15703,
#  'medical': 17072,
#  'situation': 24272,
#  'whoever': 28795,
#  'does': 8761,
#  'had': 12452,
#  'persistent': 19827,
#  'knee': 15268,
#  'operation': 18889,
#  'weeks': 28641,
#  'ago': 2005,
#  'another': 2538,
#  'three': 26566,
#  'saracens': 23154,
#  'believed': 3765,
#  'head': 12766,
#  'list': 16044,
#  'union': 27652,
#  'clubs': 6107,
#  'interested': 14272,
#  'signing': 24158,
#  'decides': 7750,
#  'move': 17823,
#  '15': 219,
#  'man': 16586,
#  'game': 11567,
#  'across': 1722,
#  'believes': 3767,
#  'would': 29108,
#  'better': 3910,
#  'playing': 20173,
#  'backs': 3294,
#  'initially': 14067,
#  'sure': 25775,
#  'step': 25226,
#  'between': 3915,
#  'centre': 5492,
#  'think': 26513,
#  'england': 9685,
#  'prefer': 20565,
#  'progress': 20847,
#  'position': 20412,
#  'back': 3265,
#  'row': 22853,
#  'where': 28742,
#  'use': 27910,
#  'skills': 24311,
#  'within': 28967,
#  'forwards': 11198,
#  'jury': 14957,
#  'whether': 28747,
#  'divide': 8689,
#  'club': 6103,
#  'balance': 3359,
#  'struck': 25479,
#  'cost': 7040,
#  'option': 18931,
#  'bringing': 4637,
#  'ready': 21541,
#  'replacement': 22149,
#  'yeading': 29253,
#  'face': 10339,
#  'newcastle': 18283,
#  'fa': 10328,
#  'cup': 7414,
#  'premiership': 20592,
#  'side': 24109,
#  'united': 27661,
#  'trip': 27140,
#  'ryman': 22979,
#  'premier': 20588,
#  'leaders': 15660,
#  'third': 26521,
#  'round': 22828,
#  'arguably': 2755,
#  'highlight': 13014,
#  'draw': 8965,
#  'potential': 20455,
#  'money': 17652,
#  'spinner': 24884,
#  'non': 18451,
#  'beat': 3649,
#  'slough': 24416,
#  'second': 23526,
#  'conference': 6573,
#  'exeter': 10147,
#  'city': 5909,
#  'knocked': 15286,
#  'doncaster': 8820,
#  'saturday': 23189,
#  'travel': 27046,
#  'old': 18795,
#  'trafford': 26961,
#  'meet': 17085,
#  'holders': 13151,
#  'manchester': 16596,
#  'january': 14661,
#  'arsenal': 2833,
#  'drawn': 8971,
#  'stoke': 25319,
#  'chelsea': 5700,
#  'host': 13292,
#  'scunthorpe': 23464,
#  'hinckley': 13040,
#  'held': 12873,
#  'brentford': 4580,
#  'goalless': 11995,
#  'sunday': 25688,
#  'luton': 16348,
#  'win': 28882,
#  'against': 1966,
#  'martin': 16779,
#  'allen': 2199,
#  'griffin': 12258,
#  'park': 19452,
#  'number': 18581,
#  'teams': 26226,
#  'difficult': 8322,
#  'games': 11578,
#  'championship': 5573,
#  'sides': 24119,
#  'weekend': 28638,
#  'placed': 20112,
#  'everton': 10035,
#  'visit': 28274,
#  'plymouth': 20239,
#  'liverpool': 16083,
#  'burnley': 4908,
#  'palace': 19343,
#  'go': 11990,
#  'sunderland': 25690,
#  'fulham': 11431,
#  'carling': 5252,
#  'semi': 23618,
#  'finalists': 10760,
#  'watford': 28559,
#  'bolton': 4283,
#  'ipswich': 14449,
#  'while': 28752,
#  'aston': 2978,
#  'villa': 28211,
#  'sheffield': 23900,
#  'strugglers': 25487,
#  'norwich': 18497,
#  'blackburn': 4062,
#  'west': 28703,
#  'brom': 4697,
#  'ham': 12510,
#  'cardiff': 5224,
#  'preston': 20655,
#  'north': 18481,
#  'respectively': 22284,
#  'southampton': 24716,
#  'northampton': 18482,
#  'having': 12731,
#  'beaten': 3651,
#  'earlier': 9183,
#  'season': 23503,
#  'middlesbrough': 17311,
#  'either': 9375,
#  'swindon': 25937,
#  'notts': 18538,
#  'county': 7104,
#  'spurs': 24988,
#  'entertain': 9741,
#  'brighton': 4628,
#  'white': 28780,
#  'hart': 12671,
#  'lane': 15519,
#  'co': 6131,
#  'utd': 27929,
#  'blackpool': 4068,
#  'derby': 8085,
#  'wigan': 28833,
#  'wolves': 29012,
#  'millwall': 17381,
#  'hull': 13395,
#  'colchester': 6205,
#  'tottenham': 26868,
#  'reading': 21538,
#  'stockport': 25313,
#  'swansea': 25888,
#  'birmingham': 4023,
#  'leeds': 15726,
#  'hartlepool': 12672,
#  'boston': 4397,
#  'milton': 17385,
#  'keynes': 15137,
#  'dons': 8837,
#  'peterborough': 19879,
#  'oldham': 18798,
#  'charlton': 5638,
#  'rochdale': 22699,
#  'sheff': 23898,
#  'rotherham': 22815,
#  'yeovil': 29271,
#  'bournemouth': 4439,
#  'chester': 5727,
#  'coventry': 7134,
#  'crewe': 7245,
#  'portsmouth': 20405,
#  'gillingham': 11866,
#  'qpr': 21171,
#  'nottm': 18537,
#  'forest': 11139,
#  'matches': 16842,
#  'played': 20169,
#  'ocean': 18702,
#  'twelve': 27311,
#  'raids': 21355,
#  'box': 4458,
#  'office': 18746,
#  'crime': 7254,
#  'caper': 5175,
#  'sequel': 23682,
#  'starring': 25135,
#  'george': 11767,
#  'clooney': 6081,
#  'brad': 4487,
#  'pitt': 20091,
#  'julia': 14922,
#  'roberts': 22678,
#  'gone': 12042,
#  'straight': 25369,
#  'chart': 5643,
#  'took': 26792,
#  '40': 850,
#  '8m': 1386,
#  '21m': 530,
#  'ticket': 26627,
#  'sales': 23062,
#  'studio': 25502,
#  'estimates': 9934,
#  'follows': 11066,
#  'master': 16823,
#  'criminals': 7261,
#  'try': 27215,
#  'pull': 21063,
#  'major': 16512,
#  'heists': 12871,
#  'week': 28637,
#  'national': 18109,
#  'treasure': 27064,
#  'place': 20110,
#  'wesley': 28700,
#  'snipes': 24532,
#  'blade': 4072,
#  'trinity': 27137,
#  '16': 249,
#  '1m': 462,
#  '4m': 971,
#  'rounding': 22832,
#  'animated': 2485,
#  'fable': 10332,
#  'polar': 20289,
#  'express': 10268,
#  'tom': 26764,
#  'hanks': 12574,
#  'festive': 10654,
#  'comedy': 6304,
#  'christmas': 5827,
#  'kranks': 15357,
#  'triumph': 27148,
#  'marks': 16742,
#  'fourth': 11224,
#  'opening': 18875,
#  'december': 7736,
#  'release': 21979,
#  'after': 1957,
#  'films': 10747,
#  'lord': 16219,
#  'rings': 22599,
#  'trilogy': 27130,
#  'narrowly': 18089,
#  '2001': 470,
#  'predecessor': 20551,
#  'eleven': 9431,
#  '38': 815,
#  '19': 347,
#  '184m': 325,
#  '95': 1429,
#  'total': 26853,
#  'remake': 22025,
#  '1960s': 410,
#  'film': 10739,
#  'frank': 11273,
#  'sinatra': 24217,
#  'rat': 21469,
#  'pack': 19291,
#  'directed': 8397,
#  'oscar': 19023,
#  'winning': 28917,
#  'director': 8404,
#  'steven': 25253,
#  'soderbergh': 24580,
#  'returns': 22396,
#  'direct': 8395,
#  'hit': 13085,
#  'reunites': 22402,
#  'matt': 16872,
#  'damon': 7560,
#  'garcia': 11601,
#  'elliott': 9461,
#  'gould': 12099,
#  'catherine': 5384,
#  'zeta': 29385,
#  'jones': 14844,
#  'joins': 14818,
#  'star': 25121,
#  'cast': 5339,
#  'fun': 11442,
#  'good': 12051,
#  'holiday': 13158,
#  'movie': 17829,
#  'dan': 7565,
#  'fellman': 10602,
#  'distribution': 8655,
#  'warner': 28502,
#  'bros': 4713,
#  'critics': 7285,
#  'less': 15809,
#  'complimentary': 6460,
#  '110m': 109,
#  '57': 1068,
#  '2m': 682,
#  'project': 20857,
#  'los': 16228,
#  'angeles': 2457,
#  'times': 26671,
#  'labelling': 15422,
#  'dispiriting': 8578,
#  'vanity': 28011,
#  'milder': 17352,
#  'review': 22438,
#  'york': 29299,
#  'dubbed': 9061,
#  'unabashedly': 27407,
#  'trivial': 27153,
#  'howard': 13347,
#  'hits': 13094,
#  'mongrel': 17660,
#  'jibe': 14763,
#  'michael': 17285,
#  'peter': 19878,
#  'hain': 12468,
#  'tory': 26845,
#  'leader': 15658,
#  'acting': 1725,
#  'attack': 3031,
#  'shows': 24059,
#  'labour': 15427,
#  'rattled': 21490,
#  'opposition': 18914,
#  'upbeat': 27830,
#  'party': 19510,
#  'spring': 24962,
#  'campaigning': 5100,
#  'tactics': 26035,
#  'proved': 20983,
#  'tories': 26829,
#  'hitting': 13097,
#  'anti': 2557,
#  'terror': 26385,
#  'debate': 7703,
#  'something': 24642,
#  'tells': 26309,
#  'me': 17027,
#  'someone': 24639,
#  'somewhere': 24646,
#  'little': 16069,
#  'bit': 4040,
#  'commons': 6371,
#  'four': 11219,
#  'stance': 25095,
#  'government': 12107,
#  'terrorism': 26387,
#  'legislation': 15748,
#  'country': 7098,
#  'risk': 22623,
#  'then': 26479,
#  'behaving': 3732,
#  'sake': 23050,
#  'anything': 2587,
#  'cling': 6053,
#  'costs': 7054,
#  'far': 10458,
#  'year': 29256,
#  'compared': 6398,
#  'fagin': 10368,
#  'shylock': 24092,
#  'flying': 11028,
#  'pig': 20025,
#  'morning': 17734,
#  'don': 8812,
#  'environment': 9781,
#  'secretary': 23534,
#  'margaret': 16699,
#  'beckett': 3677,
#  'rejected': 21949,
#  'comment': 6331,
#  'telling': 26308,
#  'pm': 20240,
#  'very': 28122,
#  'real': 21546,
#  'duty': 9137,
#  'get': 11799,
#  'focus': 11035,
#  'proposals': 20919,
#  'examples': 10080,
#  'seeing': 23563,
#  'believe': 3764,
#  'really': 21559,
#  'poor': 20348,
#  'judgement': 14900,
#  'behalf': 3729,
#  'policies': 20297,
#  'schools': 23338,
#  'taxes': 26198,
#  'immigration': 13695,
#  'striking': 25447,
#  'chord': 5802,
#  'voters': 28355,
#  'since': 24218,
#  'beginning': 3723,
#  'election': 9395,
#  've': 28053,
#  'political': 20308,
#  'weather': 28602,
#  'denied': 7997,
#  'politics': 20314,
#  'raising': 21376,
#  'case': 5326,
#  'dixon': 8708,
#  'whose': 28805,
#  'cancelled': 5124,
#  'seven': 23748,
#  'grabbed': 12121,
#  'headlines': 12778,
#  'claims': 5929,
#  'mrs': 17857,
#  'human': 13398,
#  'shield': 23932,
#  'she': 23884,
#  'blair': 4075,
#  'plans': 20138,
#  'quotas': 21268,
#  'media': 17064,
#  'coverage': 7136,
#  'racist': 21299,
#  'common': 6368,
#  'sense': 23647,
#  'pledged': 20198,
#  'cleaner': 5997,
#  'hospitals': 13290,
#  'school': 23329,
#  'discipline': 8454,
#  'promise': 20875,
#  'rid': 22538,
#  'correctness': 7005,
#  'curriculum': 7438,
#  'give': 11893,
#  'same': 23090,
#  'chance': 5577,
#  'decent': 7738,
#  'state': 25151,
#  'education': 9316,
#  'come': 6298,
#  'ordinary': 18954,
#  'family': 10432,
#  'teenage': 26258,
#  'applying': 2654,
#  'cambridge': 5079,
#  'gordon': 12075,
#  'brown': 4723,
#  'love': 16255,
#  'stressed': 25425,
#  'commitment': 6357,
#  'cut': 7467,
#  'red': 21725,
#  'tape': 26129,
#  'increase': 13872,
#  'basic': 3551,
#  'pension': 19730,
#  'line': 15999,
#  'earnings': 9194,
#  'finished': 10797,
#  'appeal': 2623,
#  'activists': 1738,
#  'day': 7655,
#  'able': 1538,
#  'your': 29312,
#  ...}

# %%
x_train_count.shape
# Out:
# (2225, 29421)

# %%
print(x_train_count[15])
# Out:
#   (0, 11495)	2
#   (0, 13801)	4
#   (0, 26462)	13
#   (0, 18726)	9
#   (0, 28955)	1
#   (0, 2429)	6
#   (0, 14340)	2
#   (0, 28852)	3
#   (0, 3620)	1
#   (0, 29260)	1
#   (0, 14510)	1
#   (0, 26730)	8
#   (0, 2395)	1
#   (0, 28749)	2
#   (0, 2994)	1
#   (0, 6764)	1
#   (0, 18837)	2
#   (0, 26588)	2
#   (0, 12684)	3
#   (0, 3706)	3
#   (0, 28740)	2
#   (0, 26501)	2
#   (0, 11102)	1
#   (0, 17721)	1
#   (0, 3744)	1
#   :	:
#   (0, 11992)	1
#   (0, 17240)	1
#   (0, 15206)	1
#   (0, 2408)	1
#   (0, 23593)	1
#   (0, 23552)	1
#   (0, 24429)	1
#   (0, 21703)	1
#   (0, 7268)	1
#   (0, 4776)	1
#   (0, 4917)	1
#   (0, 17375)	1
#   (0, 6766)	1
#   (0, 10599)	1
#   (0, 22132)	1
#   (0, 20825)	1
#   (0, 23681)	1
#   (0, 18174)	1
#   (0, 11483)	1
#   (0, 26594)	1
#   (0, 25306)	1
#   (0, 10104)	1
#   (0, 10089)	1
#   (0, 2948)	1
#   (0, 22940)	1

# %% [markdown]
# ### Transform count vectorizer into tfidf
# Calculating inverse document frequency

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
x_train_tfidf = tfidf_vectorizer.fit_transform(data['text']) 

tfidf_vectorizer.vocabulary_
# Out:
# {'tv': 27299,
#  'future': 11495,
#  'in': 13801,
#  'the': 26462,
#  'hands': 12561,
#  'of': 18726,
#  'viewers': 28191,
#  'with': 28955,
#  'home': 13183,
#  'theatre': 26464,
#  'systems': 26007,
#  'plasma': 20146,
#  'high': 13002,
#  'definition': 7862,
#  'tvs': 27302,
#  'and': 2429,
#  'digital': 8332,
#  'video': 28174,
#  'recorders': 21691,
#  'moving': 17832,
#  'into': 14340,
#  'living': 16089,
#  'room': 22779,
#  'way': 28572,
#  'people': 19740,
#  'watch': 28540,
#  'will': 28852,
#  'be': 3620,
#  'radically': 21317,
#  'different': 8316,
#  'five': 10875,
#  'years': 29260,
#  'time': 26665,
#  'that': 26454,
#  'is': 14510,
#  'according': 1650,
#  'to': 26730,
#  'an': 2395,
#  'expert': 10212,
#  'panel': 19383,
#  'which': 28749,
#  'gathered': 11644,
#  'at': 2994,
#  'annual': 2524,
#  'consumer': 6764,
#  'electronics': 9414,
#  'show': 24042,
#  'las': 15561,
#  'vegas': 28057,
#  'discuss': 8504,
#  'how': 13346,
#  'these': 26500,
#  'new': 18278,
#  'technologies': 26246,
#  'impact': 13703,
#  'one': 18837,
#  'our': 19052,
#  'favourite': 10530,
#  'pastimes': 19544,
#  'us': 27901,
#  'leading': 15662,
#  'trend': 27085,
#  'programmes': 20844,
#  'other': 19039,
#  'content': 6796,
#  'delivered': 7927,
#  'via': 28137,
#  'networks': 18258,
#  'through': 26588,
#  'cable': 5004,
#  'satellite': 23173,
#  'telecoms': 26281,
#  'companies': 6390,
#  'broadband': 4665,
#  'service': 23722,
#  'providers': 20990,
#  'front': 11379,
#  'rooms': 22780,
#  'portable': 20380,
#  'devices': 8231,
#  'most': 17758,
#  'talked': 26079,
#  'about': 1551,
#  'ces': 5519,
#  'has': 12684,
#  'been': 3706,
#  'personal': 19833,
#  'dvr': 9143,
#  'pvr': 21153,
#  'set': 23729,
#  'top': 26806,
#  'boxes': 4460,
#  'like': 15949,
#  'tivo': 26724,
#  'uk': 27376,
#  'sky': 24327,
#  'system': 26004,
#  'allow': 2219,
#  'record': 21687,
#  'store': 25345,
#  'play': 20163,
#  'pause': 19594,
#  'forward': 11197,
#  'wind': 28884,
#  'when': 28740,
#  'they': 26501,
#  'want': 28464,
#  'essentially': 9916,
#  'technology': 26248,
#  'allows': 2225,
#  'for': 11102,
#  'much': 17871,
#  'more': 17721,
#  'personalised': 19836,
#  'are': 2741,
#  'also': 2251,
#  'being': 3744,
#  'built': 4826,
#  'sets': 23735,
#  'big': 3961,
#  'business': 4934,
#  'japan': 14664,
#  'but': 4944,
#  'slower': 24426,
#  'take': 26057,
#  'off': 18730,
#  'europe': 9974,
#  'because': 3672,
#  'lack': 15433,
#  'programming': 20845,
#  'not': 18502,
#  'only': 18849,
#  'can': 5112,
#  'adverts': 1892,
#  'forget': 11147,
#  'abiding': 1532,
#  'by': 4980,
#  'network': 18255,
#  'channel': 5596,
#  'schedules': 23305,
#  'putting': 21148,
#  'together': 26744,
#  'their': 26471,
#  'own': 19254,
#  'la': 15416,
#  'carte': 5305,
#  'entertainment': 9746,
#  'some': 24635,
#  'worried': 29091,
#  'what': 28726,
#  'it': 14557,
#  'means': 17037,
#  'them': 26474,
#  'terms': 26372,
#  'advertising': 1891,
#  'revenues': 22427,
#  'as': 2868,
#  'well': 28674,
#  'brand': 4512,
#  'identity': 13568,
#  'viewer': 28190,
#  'loyalty': 16278,
#  'channels': 5598,
#  'although': 2262,
#  'leads': 15664,
#  'this': 26531,
#  'moment': 17639,
#  'concern': 6521,
#  'raised': 21374,
#  'particularly': 19493,
#  'growing': 12313,
#  'uptake': 27879,
#  'services': 23723,
#  'happens': 12595,
#  'here': 12930,
#  'today': 26737,
#  'we': 28581,
#  'see': 23558,
#  'nine': 18387,
#  'months': 17692,
#  'adam': 1753,
#  'hume': 13412,
#  'bbc': 3613,
#  'broadcast': 4667,
#  'futurologist': 11500,
#  'told': 26754,
#  'news': 18296,
#  'website': 28622,
#  'likes': 15959,
#  'there': 26490,
#  'no': 18414,
#  'issues': 14553,
#  'lost': 16237,
#  'revenue': 22426,
#  'yet': 29276,
#  'pressing': 20647,
#  'issue': 14549,
#  'commercial': 6342,
#  'broadcasters': 4669,
#  'important': 13748,
#  'everyone': 10039,
#  'talking': 26081,
#  'brands': 4517,
#  'rather': 21476,
#  'than': 26445,
#  'said': 23041,
#  'tim': 26662,
#  'hanlon': 12576,
#  'from': 11377,
#  'communications': 6378,
#  'firm': 10842,
#  'starcom': 25125,
#  'mediavest': 17070,
#  'reality': 21556,
#  'connections': 6653,
#  'anybody': 2582,
#  'producer': 20803,
#  'he': 12765,
#  'added': 1772,
#  'challenge': 5558,
#  'now': 18557,
#  'hard': 12610,
#  'promote': 20879,
#  'programme': 20840,
#  'so': 24554,
#  'choice': 5783,
#  'stacey': 25040,
#  'jolna': 14835,
#  'senior': 23642,
#  'vice': 28151,
#  'president': 20637,
#  'guide': 12358,
#  'group': 12306,
#  'find': 10775,
#  'simplified': 24197,
#  'or': 18936,
#  'could': 7070,
#  'leaf': 15666,
#  'out': 19058,
#  'google': 12066,
#  'book': 4325,
#  'search': 23493,
#  'engine': 9678,
#  'instead': 14183,
#  'scheduler': 23304,
#  'help': 12892,
#  'kind': 15209,
#  'model': 17580,
#  'might': 17328,
#  'work': 29060,
#  'younger': 29308,
#  'ipod': 14444,
#  'generation': 11723,
#  'used': 27912,
#  'taking': 26065,
#  'control': 6861,
#  'gadgets': 11517,
#  'on': 18832,
#  'suit': 25656,
#  'recognised': 21664,
#  'older': 18796,
#  'generations': 11724,
#  'comfortable': 6309,
#  'familiar': 10428,
#  'know': 15292,
#  'getting': 11804,
#  'perhaps': 19783,
#  'do': 8728,
#  'put': 21143,
#  'mr': 17855,
#  'suggested': 25645,
#  'end': 9620,
#  'you': 29305,
#  'have': 12726,
#  'kids': 15179,
#  'just': 14959,
#  'diapers': 8273,
#  'who': 28793,
#  'pushing': 21142,
#  'buttons': 4961,
#  'already': 2249,
#  'everything': 10040,
#  'possible': 20427,
#  'available': 3173,
#  'ultimately': 27387,
#  'tell': 26306,
#  'market': 16732,
#  '50': 979,
#  '000': 1,
#  'showcased': 24046,
#  'many': 16663,
#  'enhancing': 9693,
#  'watching': 28548,
#  'experience': 10203,
#  'everywhere': 10041,
#  'models': 17583,
#  'lcd': 15649,
#  'liquid': 16032,
#  'crystal': 7362,
#  'display': 8583,
#  'launched': 15598,
#  'capability': 5168,
#  'external': 10287,
#  'such': 25610,
#  'example': 10079,
#  'humax': 13406,
#  '26': 601,
#  'inch': 13833,
#  '80': 1296,
#  'hour': 13325,
#  'dvd': 9140,
#  'recorder': 21690,
#  'biggest': 3963,
#  'directtv': 8410,
#  'even': 10015,
#  'its': 14571,
#  'branded': 4513,
#  '100': 69,
#  'hours': 13327,
#  'recording': 21692,
#  'instant': 14177,
#  'replay': 22153,
#  'function': 11443,
#  'rewind': 22477,
#  'up': 27829,
#  '90': 1389,
#  'microsoft': 17303,
#  'chief': 5741,
#  'bill': 3973,
#  'gates': 11639,
#  'announced': 2513,
#  'his': 13073,
#  'pre': 20525,
#  'keynote': 15138,
#  'speech': 24832,
#  'partnership': 19505,
#  'called': 5056,
#  'tivotogo': 26726,
#  'recorded': 21689,
#  'windows': 28890,
#  'pcs': 19637,
#  'mobile': 17564,
#  'all': 2180,
#  'reflect': 21799,
#  'increasing': 13875,
#  'freeing': 11316,
#  'multimedia': 17912,
#  'worldcom': 29085,
#  'boss': 4394,
#  'left': 15729,
#  'books': 4336,
#  'alone': 2239,
#  'former': 11166,
#  'bernie': 3871,
#  'ebbers': 9238,
#  'accused': 1680,
#  'overseeing': 19204,
#  '11bn': 133,
#  '8bn': 1382,
#  'fraud': 11289,
#  'never': 18268,
#  'made': 16433,
#  'accounting': 1660,
#  'decisions': 7755,
#  'witness': 28972,
#  'jurors': 14956,
#  'david': 7643,
#  'myers': 17998,
#  'comments': 6340,
#  'under': 27490,
#  'questioning': 21226,
#  'defence': 7831,
#  'lawyers': 15635,
#  'arguing': 2759,
#  'was': 28521,
#  'responsible': 22298,
#  'problems': 20777,
#  'phone': 19952,
#  'company': 6393,
#  'collapsed': 6226,
#  '2002': 473,
#  'prosecutors': 20937,
#  'claim': 5924,
#  'losses': 16235,
#  'were': 28694,
#  'hidden': 12991,
#  'protect': 20951,
#  'shares': 23852,
#  'pleaded': 20186,
#  'guilty': 12372,
#  'assisting': 2957,
#  'monday': 17647,
#  'lawyer': 15634,
#  'reid': 21904,
#  'weingarten': 28655,
#  'tried': 27119,
#  'distance': 8625,
#  'client': 6034,
#  'allegations': 2191,
#  'during': 9128,
#  'cross': 7305,
#  'examination': 10074,
#  'asked': 2905,
#  'if': 13597,
#  'ever': 10025,
#  'knew': 15271,
#  'make': 16519,
#  'decision': 7754,
#  'am': 2280,
#  'aware': 3214,
#  'replied': 22158,
#  'did': 8295,
#  'entry': 9774,
#  'pressed': 20645,
#  'admitted': 1835,
#  'ordered': 18950,
#  'false': 10418,
#  'entries': 9772,
#  'request': 22196,
#  'financial': 10766,
#  'officer': 18747,
#  'scott': 23399,
#  'sullivan': 25671,
#  'trying': 27217,
#  'paint': 19325,
#  'testify': 26401,
#  'later': 15575,
#  'trial': 27098,
#  'mastermind': 16827,
#  'behind': 3737,
#  'house': 13328,
#  'cards': 5227,
#  'team': 26223,
#  'meanwhile': 17040,
#  'looking': 16199,
#  'portray': 20399,
#  'him': 13037,
#  'affable': 1921,
#  'admission': 1830,
#  'pe': 19644,
#  'graduate': 12137,
#  'economist': 9270,
#  'whatever': 28727,
#  'abilities': 1534,
#  'transformed': 27004,
#  'relative': 21968,
#  'unknown': 27675,
#  '160bn': 254,
#  'giant': 11826,
#  'investor': 14405,
#  'darling': 7611,
#  'late': 15573,
#  '1990s': 447,
#  'mounted': 17808,
#  'however': 13353,
#  'competition': 6424,
#  'increased': 13873,
#  'boom': 4340,
#  'petered': 19881,
#  'finally': 10761,
#  'shareholders': 23849,
#  '180bn': 315,
#  '20': 467,
#  'workers': 29064,
#  'jobs': 14793,
#  'expected': 10193,
#  'last': 15568,
#  'two': 27328,
#  'found': 11211,
#  'ceo': 5500,
#  'faces': 10342,
#  'substantial': 25576,
#  'jail': 14621,
#  'sentence': 23661,
#  'firmly': 10846,
#  'declared': 7768,
#  'innocence': 14100,
#  'tigers': 26649,
#  'wary': 28520,
#  'farrell': 10486,
#  'gamble': 11563,
#  'leicester': 15761,
#  'say': 23229,
#  'rushed': 22956,
#  'making': 16529,
#  'bid': 3953,
#  'andy': 2448,
#  'should': 24031,
#  'great': 12204,
#  'britain': 4645,
#  'rugby': 22909,
#  'league': 15669,
#  'captain': 5197,
#  'decide': 7746,
#  'switch': 25944,
#  'codes': 6178,
#  'else': 9470,
#  'involved': 14423,
#  'process': 20787,
#  'still': 25278,
#  'away': 3216,
#  'going': 12021,
#  'next': 18306,
#  'stage': 25050,
#  'john': 14809,
#  'wells': 28681,
#  'radio': 21321,
#  'lot': 16239,
#  'unknowns': 27676,
#  'least': 15703,
#  'medical': 17072,
#  'situation': 24272,
#  'whoever': 28795,
#  'does': 8761,
#  'had': 12452,
#  'persistent': 19827,
#  'knee': 15268,
#  'operation': 18889,
#  'weeks': 28641,
#  'ago': 2005,
#  'another': 2538,
#  'three': 26566,
#  'saracens': 23154,
#  'believed': 3765,
#  'head': 12766,
#  'list': 16044,
#  'union': 27652,
#  'clubs': 6107,
#  'interested': 14272,
#  'signing': 24158,
#  'decides': 7750,
#  'move': 17823,
#  '15': 219,
#  'man': 16586,
#  'game': 11567,
#  'across': 1722,
#  'believes': 3767,
#  'would': 29108,
#  'better': 3910,
#  'playing': 20173,
#  'backs': 3294,
#  'initially': 14067,
#  'sure': 25775,
#  'step': 25226,
#  'between': 3915,
#  'centre': 5492,
#  'think': 26513,
#  'england': 9685,
#  'prefer': 20565,
#  'progress': 20847,
#  'position': 20412,
#  'back': 3265,
#  'row': 22853,
#  'where': 28742,
#  'use': 27910,
#  'skills': 24311,
#  'within': 28967,
#  'forwards': 11198,
#  'jury': 14957,
#  'whether': 28747,
#  'divide': 8689,
#  'club': 6103,
#  'balance': 3359,
#  'struck': 25479,
#  'cost': 7040,
#  'option': 18931,
#  'bringing': 4637,
#  'ready': 21541,
#  'replacement': 22149,
#  'yeading': 29253,
#  'face': 10339,
#  'newcastle': 18283,
#  'fa': 10328,
#  'cup': 7414,
#  'premiership': 20592,
#  'side': 24109,
#  'united': 27661,
#  'trip': 27140,
#  'ryman': 22979,
#  'premier': 20588,
#  'leaders': 15660,
#  'third': 26521,
#  'round': 22828,
#  'arguably': 2755,
#  'highlight': 13014,
#  'draw': 8965,
#  'potential': 20455,
#  'money': 17652,
#  'spinner': 24884,
#  'non': 18451,
#  'beat': 3649,
#  'slough': 24416,
#  'second': 23526,
#  'conference': 6573,
#  'exeter': 10147,
#  'city': 5909,
#  'knocked': 15286,
#  'doncaster': 8820,
#  'saturday': 23189,
#  'travel': 27046,
#  'old': 18795,
#  'trafford': 26961,
#  'meet': 17085,
#  'holders': 13151,
#  'manchester': 16596,
#  'january': 14661,
#  'arsenal': 2833,
#  'drawn': 8971,
#  'stoke': 25319,
#  'chelsea': 5700,
#  'host': 13292,
#  'scunthorpe': 23464,
#  'hinckley': 13040,
#  'held': 12873,
#  'brentford': 4580,
#  'goalless': 11995,
#  'sunday': 25688,
#  'luton': 16348,
#  'win': 28882,
#  'against': 1966,
#  'martin': 16779,
#  'allen': 2199,
#  'griffin': 12258,
#  'park': 19452,
#  'number': 18581,
#  'teams': 26226,
#  'difficult': 8322,
#  'games': 11578,
#  'championship': 5573,
#  'sides': 24119,
#  'weekend': 28638,
#  'placed': 20112,
#  'everton': 10035,
#  'visit': 28274,
#  'plymouth': 20239,
#  'liverpool': 16083,
#  'burnley': 4908,
#  'palace': 19343,
#  'go': 11990,
#  'sunderland': 25690,
#  'fulham': 11431,
#  'carling': 5252,
#  'semi': 23618,
#  'finalists': 10760,
#  'watford': 28559,
#  'bolton': 4283,
#  'ipswich': 14449,
#  'while': 28752,
#  'aston': 2978,
#  'villa': 28211,
#  'sheffield': 23900,
#  'strugglers': 25487,
#  'norwich': 18497,
#  'blackburn': 4062,
#  'west': 28703,
#  'brom': 4697,
#  'ham': 12510,
#  'cardiff': 5224,
#  'preston': 20655,
#  'north': 18481,
#  'respectively': 22284,
#  'southampton': 24716,
#  'northampton': 18482,
#  'having': 12731,
#  'beaten': 3651,
#  'earlier': 9183,
#  'season': 23503,
#  'middlesbrough': 17311,
#  'either': 9375,
#  'swindon': 25937,
#  'notts': 18538,
#  'county': 7104,
#  'spurs': 24988,
#  'entertain': 9741,
#  'brighton': 4628,
#  'white': 28780,
#  'hart': 12671,
#  'lane': 15519,
#  'co': 6131,
#  'utd': 27929,
#  'blackpool': 4068,
#  'derby': 8085,
#  'wigan': 28833,
#  'wolves': 29012,
#  'millwall': 17381,
#  'hull': 13395,
#  'colchester': 6205,
#  'tottenham': 26868,
#  'reading': 21538,
#  'stockport': 25313,
#  'swansea': 25888,
#  'birmingham': 4023,
#  'leeds': 15726,
#  'hartlepool': 12672,
#  'boston': 4397,
#  'milton': 17385,
#  'keynes': 15137,
#  'dons': 8837,
#  'peterborough': 19879,
#  'oldham': 18798,
#  'charlton': 5638,
#  'rochdale': 22699,
#  'sheff': 23898,
#  'rotherham': 22815,
#  'yeovil': 29271,
#  'bournemouth': 4439,
#  'chester': 5727,
#  'coventry': 7134,
#  'crewe': 7245,
#  'portsmouth': 20405,
#  'gillingham': 11866,
#  'qpr': 21171,
#  'nottm': 18537,
#  'forest': 11139,
#  'matches': 16842,
#  'played': 20169,
#  'ocean': 18702,
#  'twelve': 27311,
#  'raids': 21355,
#  'box': 4458,
#  'office': 18746,
#  'crime': 7254,
#  'caper': 5175,
#  'sequel': 23682,
#  'starring': 25135,
#  'george': 11767,
#  'clooney': 6081,
#  'brad': 4487,
#  'pitt': 20091,
#  'julia': 14922,
#  'roberts': 22678,
#  'gone': 12042,
#  'straight': 25369,
#  'chart': 5643,
#  'took': 26792,
#  '40': 850,
#  '8m': 1386,
#  '21m': 530,
#  'ticket': 26627,
#  'sales': 23062,
#  'studio': 25502,
#  'estimates': 9934,
#  'follows': 11066,
#  'master': 16823,
#  'criminals': 7261,
#  'try': 27215,
#  'pull': 21063,
#  'major': 16512,
#  'heists': 12871,
#  'week': 28637,
#  'national': 18109,
#  'treasure': 27064,
#  'place': 20110,
#  'wesley': 28700,
#  'snipes': 24532,
#  'blade': 4072,
#  'trinity': 27137,
#  '16': 249,
#  '1m': 462,
#  '4m': 971,
#  'rounding': 22832,
#  'animated': 2485,
#  'fable': 10332,
#  'polar': 20289,
#  'express': 10268,
#  'tom': 26764,
#  'hanks': 12574,
#  'festive': 10654,
#  'comedy': 6304,
#  'christmas': 5827,
#  'kranks': 15357,
#  'triumph': 27148,
#  'marks': 16742,
#  'fourth': 11224,
#  'opening': 18875,
#  'december': 7736,
#  'release': 21979,
#  'after': 1957,
#  'films': 10747,
#  'lord': 16219,
#  'rings': 22599,
#  'trilogy': 27130,
#  'narrowly': 18089,
#  '2001': 470,
#  'predecessor': 20551,
#  'eleven': 9431,
#  '38': 815,
#  '19': 347,
#  '184m': 325,
#  '95': 1429,
#  'total': 26853,
#  'remake': 22025,
#  '1960s': 410,
#  'film': 10739,
#  'frank': 11273,
#  'sinatra': 24217,
#  'rat': 21469,
#  'pack': 19291,
#  'directed': 8397,
#  'oscar': 19023,
#  'winning': 28917,
#  'director': 8404,
#  'steven': 25253,
#  'soderbergh': 24580,
#  'returns': 22396,
#  'direct': 8395,
#  'hit': 13085,
#  'reunites': 22402,
#  'matt': 16872,
#  'damon': 7560,
#  'garcia': 11601,
#  'elliott': 9461,
#  'gould': 12099,
#  'catherine': 5384,
#  'zeta': 29385,
#  'jones': 14844,
#  'joins': 14818,
#  'star': 25121,
#  'cast': 5339,
#  'fun': 11442,
#  'good': 12051,
#  'holiday': 13158,
#  'movie': 17829,
#  'dan': 7565,
#  'fellman': 10602,
#  'distribution': 8655,
#  'warner': 28502,
#  'bros': 4713,
#  'critics': 7285,
#  'less': 15809,
#  'complimentary': 6460,
#  '110m': 109,
#  '57': 1068,
#  '2m': 682,
#  'project': 20857,
#  'los': 16228,
#  'angeles': 2457,
#  'times': 26671,
#  'labelling': 15422,
#  'dispiriting': 8578,
#  'vanity': 28011,
#  'milder': 17352,
#  'review': 22438,
#  'york': 29299,
#  'dubbed': 9061,
#  'unabashedly': 27407,
#  'trivial': 27153,
#  'howard': 13347,
#  'hits': 13094,
#  'mongrel': 17660,
#  'jibe': 14763,
#  'michael': 17285,
#  'peter': 19878,
#  'hain': 12468,
#  'tory': 26845,
#  'leader': 15658,
#  'acting': 1725,
#  'attack': 3031,
#  'shows': 24059,
#  'labour': 15427,
#  'rattled': 21490,
#  'opposition': 18914,
#  'upbeat': 27830,
#  'party': 19510,
#  'spring': 24962,
#  'campaigning': 5100,
#  'tactics': 26035,
#  'proved': 20983,
#  'tories': 26829,
#  'hitting': 13097,
#  'anti': 2557,
#  'terror': 26385,
#  'debate': 7703,
#  'something': 24642,
#  'tells': 26309,
#  'me': 17027,
#  'someone': 24639,
#  'somewhere': 24646,
#  'little': 16069,
#  'bit': 4040,
#  'commons': 6371,
#  'four': 11219,
#  'stance': 25095,
#  'government': 12107,
#  'terrorism': 26387,
#  'legislation': 15748,
#  'country': 7098,
#  'risk': 22623,
#  'then': 26479,
#  'behaving': 3732,
#  'sake': 23050,
#  'anything': 2587,
#  'cling': 6053,
#  'costs': 7054,
#  'far': 10458,
#  'year': 29256,
#  'compared': 6398,
#  'fagin': 10368,
#  'shylock': 24092,
#  'flying': 11028,
#  'pig': 20025,
#  'morning': 17734,
#  'don': 8812,
#  'environment': 9781,
#  'secretary': 23534,
#  'margaret': 16699,
#  'beckett': 3677,
#  'rejected': 21949,
#  'comment': 6331,
#  'telling': 26308,
#  'pm': 20240,
#  'very': 28122,
#  'real': 21546,
#  'duty': 9137,
#  'get': 11799,
#  'focus': 11035,
#  'proposals': 20919,
#  'examples': 10080,
#  'seeing': 23563,
#  'believe': 3764,
#  'really': 21559,
#  'poor': 20348,
#  'judgement': 14900,
#  'behalf': 3729,
#  'policies': 20297,
#  'schools': 23338,
#  'taxes': 26198,
#  'immigration': 13695,
#  'striking': 25447,
#  'chord': 5802,
#  'voters': 28355,
#  'since': 24218,
#  'beginning': 3723,
#  'election': 9395,
#  've': 28053,
#  'political': 20308,
#  'weather': 28602,
#  'denied': 7997,
#  'politics': 20314,
#  'raising': 21376,
#  'case': 5326,
#  'dixon': 8708,
#  'whose': 28805,
#  'cancelled': 5124,
#  'seven': 23748,
#  'grabbed': 12121,
#  'headlines': 12778,
#  'claims': 5929,
#  'mrs': 17857,
#  'human': 13398,
#  'shield': 23932,
#  'she': 23884,
#  'blair': 4075,
#  'plans': 20138,
#  'quotas': 21268,
#  'media': 17064,
#  'coverage': 7136,
#  'racist': 21299,
#  'common': 6368,
#  'sense': 23647,
#  'pledged': 20198,
#  'cleaner': 5997,
#  'hospitals': 13290,
#  'school': 23329,
#  'discipline': 8454,
#  'promise': 20875,
#  'rid': 22538,
#  'correctness': 7005,
#  'curriculum': 7438,
#  'give': 11893,
#  'same': 23090,
#  'chance': 5577,
#  'decent': 7738,
#  'state': 25151,
#  'education': 9316,
#  'come': 6298,
#  'ordinary': 18954,
#  'family': 10432,
#  'teenage': 26258,
#  'applying': 2654,
#  'cambridge': 5079,
#  'gordon': 12075,
#  'brown': 4723,
#  'love': 16255,
#  'stressed': 25425,
#  'commitment': 6357,
#  'cut': 7467,
#  'red': 21725,
#  'tape': 26129,
#  'increase': 13872,
#  'basic': 3551,
#  'pension': 19730,
#  'line': 15999,
#  'earnings': 9194,
#  'finished': 10797,
#  'appeal': 2623,
#  'activists': 1738,
#  'day': 7655,
#  'able': 1538,
#  'your': 29312,
#  ...}

# %%
x_train_tfidf.shape
# Out:
# (2225, 29421)

# %%
print(x_train_tfidf[15])
# Out:
#   (0, 22940)	0.03762214126336901
#   (0, 2948)	0.0509409236776086
#   (0, 10089)	0.06981179437208619
#   (0, 10104)	0.043640674374489895
#   (0, 25306)	0.04331658623558077
#   (0, 26594)	0.05521129576584879
#   (0, 11483)	0.03425691772201353
#   (0, 18174)	0.03731684355489801
#   (0, 23681)	0.039443696544706294
#   (0, 20825)	0.046240612976897
#   (0, 22132)	0.065541422283846
#   (0, 10599)	0.041923535563925994
#   (0, 6766)	0.04321073576201849
#   (0, 17375)	0.04408891365788541
#   (0, 4917)	0.06251154506896749
#   (0, 4776)	0.065541422283846
#   (0, 7268)	0.053682233979380184
#   (0, 21703)	0.06391790216496572
#   (0, 24429)	0.06070161241172701
#   (0, 23552)	0.049507175061705364
#   (0, 23593)	0.0844122929783236
#   (0, 2408)	0.042696876120132315
#   (0, 15206)	0.057811234368255894
#   (0, 17240)	0.04353153315462155
#   (0, 11992)	0.04321073576201849
#   :	:
#   (0, 3744)	0.023561865350246923
#   (0, 17721)	0.017870201923334023
#   (0, 11102)	0.011226274875132187
#   (0, 26501)	0.03492083190497568
#   (0, 28740)	0.04159225642155242
#   (0, 3706)	0.04817930832741206
#   (0, 12684)	0.03778546954454391
#   (0, 26588)	0.05695880551882702
#   (0, 18837)	0.03645516336734449
#   (0, 6764)	0.04137865370972304
#   (0, 2994)	0.012946256808771638
#   (0, 28749)	0.031645102906973886
#   (0, 2395)	0.015214911669322928
#   (0, 26730)	0.08463563022960623
#   (0, 14510)	0.012062130291754276
#   (0, 29260)	0.023146283561132013
#   (0, 3620)	0.013180913362187408
#   (0, 28852)	0.044685221372668504
#   (0, 14340)	0.04318029424718327
#   (0, 2429)	0.06376253139460895
#   (0, 28955)	0.012537761095054806
#   (0, 18726)	0.09551497944871017
#   (0, 26462)	0.13691643506921203
#   (0, 13801)	0.042527455661662154
#   (0, 11495)	0.06534409462121221

# %%
idf_scores = list(zip(tfidf_vectorizer.get_feature_names(), tfidf_vectorizer.idf_))

# %%
idf_scores[4000:4050]
# Out:
# [('biocidal', 8.014814351275545),
#  ('biodiversity', 8.014814351275545),
#  ('biogen', 8.014814351275545),
#  ('biographer', 8.014814351275545),
#  ('biography', 6.143012174373953),
#  ('biological', 7.3216671707156),
#  ('biology', 8.014814351275545),
#  ('biometric', 6.916202062607435),
#  ('biometrics', 7.60934924316738),
#  ('biopic', 5.817589773939326),
#  ('biotech', 8.014814351275545),
#  ('bioware', 8.014814351275545),
#  ('bipedal', 8.014814351275545),
#  ('bipin', 8.014814351275545),
#  ('birch', 8.014814351275545),
#  ('birchfield', 7.3216671707156),
#  ('bird', 6.628519990155654),
#  ('birds', 8.014814351275545),
#  ('birgit', 7.60934924316738),
#  ('birkbeck', 8.014814351275545),
#  ('birkenhead', 7.09852361940139),
#  ('birkett', 7.60934924316738),
#  ('birkin', 8.014814351275545),
#  ('birmingham', 4.776135899111164),
#  ('birth', 5.874748187779274),
#  ('birthday', 5.99991133073328),
#  ('birthdays', 7.3216671707156),
#  ('birthistle', 8.014814351275545),
#  ('birthplace', 8.014814351275545),
#  ('births', 8.014814351275545),
#  ('biscan', 7.60934924316738),
#  ('biscuit', 7.60934924316738),
#  ('bisected', 8.014814351275545),
#  ('bisexual', 8.014814351275545),
#  ('bisexuality', 8.014814351275545),
#  ('bishop', 7.09852361940139),
#  ('bishops', 8.014814351275545),
#  ('bisnis', 8.014814351275545),
#  ('bissell', 8.014814351275545),
#  ('bisset', 8.014814351275545),
#  ('bit', 3.96302940347224),
#  ('bitches', 8.014814351275545),
#  ('bite', 6.51073695449927),
#  ('bites', 8.014814351275545),
#  ('biting', 8.014814351275545),
#  ('bits', 6.628519990155654),
#  ('bitter', 6.51073695449927),
#  ('bitterly', 6.916202062607435),
#  ('bittersweet', 8.014814351275545),
#  ('bittorrent', 6.51073695449927)]

# %% [markdown]
# ### Split data into train, test data

# %%
from sklearn.model_selection import train_test_split

Y = data['category']

x_train, x_test, y_train, y_test = train_test_split(x_train_tfidf, Y, test_size=0.2)

# %%
x_train.shape, y_train.shape
# Out:
# ((1780, 29421), (1780,))

# %%
x_test.shape, y_test.shape
# Out:
# ((445, 29421), (445,))

# %% [markdown]
# ### Decision Tree
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=10)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=10, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred = clf.predict(x_test)

y_pred[0:10]
# Out:
# array(['sport', 'politics', 'entertainment', 'politics', 'business',
#        'tech', 'sport', 'business', 'entertainment', 'sport'],
#       dtype=object)

# %% [markdown]
# ### Accuracy score

# %%
from sklearn.metrics import accuracy_score

print("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.7775280898876404

# %% [markdown]
# ### Table for predicted and actual values

# %%
df_y = pd.DataFrame({'y_test' : y_test, 'y_pred' : y_pred})

df_y.sample(10)
# Out:
#              y_test         y_pred
# 560           sport          sport
# 1724           tech       business
# 211        politics       politics
# 1964          sport          sport
# 1677       business       business
# 939   entertainment  entertainment
# 2065           tech           tech
# 2109  entertainment  entertainment
# 812        politics       politics
# 1073  entertainment  entertainment
